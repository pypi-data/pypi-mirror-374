# %%
import agrigee_lite as agl
import geopandas as gpd
import ee
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import agrigee_lite as agl
#       2 import geopandas as gpd
#       3 import ee
#
# File ~/git/AgriGEE.lite/agrigee_lite/__init__.py:5
#       1 from warnings import simplefilter
#       3 import pandas as pd
# ----> 5 from agrigee_lite import get, sat, vis
#       6 from agrigee_lite.ee_utils import ee_get_tasks_status as get_all_tasks
#       7 from agrigee_lite.misc import quadtree_clustering, random_points_from_gdf
#
# File ~/git/AgriGEE.lite/agrigee_lite/get/__init__.py:2
#       1 from agrigee_lite.get.image import download_multiple_images as images
# ----> 2 from agrigee_lite.get.sits import download_multiple_sits_chunks_gcs as multiple_sits_gcs
#       3 from agrigee_lite.get.sits import download_multiple_sits_chunks_gdrive as multiple_sits_gdrive
# ...

# %%
ee.Initialize(opt_url="https://earthengine-highvolume.googleapis.com", project="ee-mateuspsilva")

# %%
sat = agl.sat.PALSAR2ScanSAR(indices=["rvi"])

# %%
gdf = gpd.read_parquet("data/brazil_sampled_cc.parquet")

# %%
row = gdf.iloc[0]

# %%
agl.get.sits(row.geometry, row.start_date, row.end_date, sat)
# Out:
#     indexnum  timestamp           hh           hv  validPixelsCount
# 0          0 2022-10-04  1966.938016   948.000000              1370
# 1          0 2022-10-09  2221.050791   875.063386              1370
# 2          0 2022-11-06  1787.085336   738.791667              1370
# 3          0 2022-11-15  2092.668206   836.023223              1370
# 4          0 2022-11-20  2224.134921   859.900000              1370
# 5          0 2022-12-13  3920.797803  1716.924668              1370
# 6          0 2022-12-18  4364.889688  1799.966261              1370
# 7          0 2022-12-27  4425.244784  2357.666667              1370
# 8          0 2023-01-01  4685.297903  2356.857143              1370
# 9          0 2023-01-24  4814.000000  2504.428571              1370
# 10         0 2023-01-29  5028.200000  2582.500000              1370
# 11         0 2023-02-07  5065.243302  2295.300926              1370
# 12         0 2023-02-12  4910.335404  2294.689276              1370
# ...

# %%
agl.vis.sits(row.geometry, row.start_date, row.end_date, sat, "rvi")

# %%
agl.vis.sits(row.geometry, row.start_date, row.end_date, sat, "rvi")

# %%
s1_sat = agl.sat.Sentinel1(indices=["ravi"])

# %%
gdf = gdf[(gdf.start_date >= s1_sat.startDate) & (gdf.end_date <= s1_sat.endDate)].reset_index(drop=True)

# %%
row = gdf.iloc[5]

# %%
agl.vis.sits(row.geometry, row.start_date, row.end_date, s1_sat, "ravi")

# %%
agl.vis.sits(row.geometry, row.start_date, row.end_date, sat, "rvi")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
agl.vis.sits(row.geometry, row.start_date, row.end_date, sat, "hv")
