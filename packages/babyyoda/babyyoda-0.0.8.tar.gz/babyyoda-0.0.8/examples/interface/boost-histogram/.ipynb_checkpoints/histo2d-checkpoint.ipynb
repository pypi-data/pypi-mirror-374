# %%
import babyyoda
import mplhep
print(babyyoda.__version__)
# Out:
# 0.0.7.dev16

# %%
h = babyyoda.read("../../../tests/test_histo1d_v3.yoda")['/']
h

# %%
bh = h.to_boost_histogram()

# %%
h.plot()
mplhep.histplot(bh,w2=bh.variances(),w2method="sqrt", binwnorm=1.0,histtype="band")
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f9a30c14740>, errorbar=None, legend_artist=None)]
