# %%
import babyyoda
import mplhep
print(babyyoda.__version__)
# Out:
# 0.0.7.dev16

# %%
h = babyyoda.read("../../../tests/test_histo1d_v3.yoda")['/']
h

# %%
bh = h.to_boost_histogram()

# %%
mplhep.histplot(bh,w2=bh.variances(),w2method="sqrt")
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f9a33de8980>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]
