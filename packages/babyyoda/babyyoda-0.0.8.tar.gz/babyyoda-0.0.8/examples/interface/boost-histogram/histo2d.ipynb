# %%
import mplhep

import babyyoda

print(babyyoda.__version__)
# Out:
# 0.0.7.dev16

# %%
h = babyyoda.read("../../../tests/test_histo2d_v3.yoda")["/"]
h

# %%
bh = h.to_boost_histogram()

# %%
mplhep.hist2dplot(bh, binwnorm=1.0)
# Out:
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f2779fa8da0>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f2779f9f500>, text=[])
