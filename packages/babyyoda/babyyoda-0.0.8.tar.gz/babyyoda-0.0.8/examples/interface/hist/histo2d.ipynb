# %%
import matplotlib.pyplot as plt
import mplhep

import babyyoda

# %%
h = babyyoda.read("../../../tests/test_histo2d_v2.yoda")["/ALICE_2020_I1797621/GGPdfXQ"]

# %%
h.plot()
plt.xscale("log")

# %%
hh = h.to_hist()

# %%
mplhep.hist2dplot(hh, binwnorm=1.0)
plt.xscale("log")
