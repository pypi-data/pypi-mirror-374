# %%
import mplhep
import babyyoda

# %%
h = babyyoda.read("../../../tests/test_histo1d_v3.yoda")['/']
h

# %%
hh = h.to_hist()

# %%
h.plot()
mplhep.histplot(hh,w2=hh.variances(),w2method="sqrt", binwnorm=1.0,histtype="band")
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7fdbe41f2690>, errorbar=None, legend_artist=None)]
